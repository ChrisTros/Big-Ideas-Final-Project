# %%
import pandas as pd
import numpy as np
import geopandas as gpd
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
libraries = pd.read_csv("libraries.csv")
libraries.head(50)
# Out:
#     _id  CLPID                                            Name  \
# 0     2  CLP01                               ALLEGHENY LIBRARY
# 1     3  CLP02                               BEECHVIEW LIBRARY
# 2     4  CLP03                               BROOKLINE LIBRARY
# 3     5  CLP04                                 CARRICK LIBRARY
# 4     6  CLP05                     DOWNTOWN & BUSINESS LIBRARY
# 5     7  CLP06                            EAST LIBERTY LIBRARY
# 6     8  CLP07                               HAZELWOOD LIBRARY
# 7     9  CLP08                           HILL DISTRICT LIBRARY
# 8    10  CLP09                                HOMEWOOD LIBRARY
# 9    11  CLP10                               KNOXVILLE LIBRARY
# 10   12  CLP11                           LAWRENCEVILLE LIBRARY
# 11   13  CLP12  LIBRARY FOR THE BLIND & PHYSICALLY HANDICAPPED
# 12   14  CLP13                          MAIN (OAKLAND) LIBRARY
# 13   15  CLP14                        MOUNT WASHINGTON LIBRARY
# 14   16  CLP15                                SHERADEN LIBRARY
# 15   17  CLP16                              SOUTH SIDE LIBRARY
# 16   18  CLP17                           SQUIRREL HILL LIBRARY
# 17   19  CLP18                                WEST END LIBRARY
# 18   20  CLP19                               WOODS RUN LIBRARY
#
#                    Address        City State        Zip4     County  \
# 0          1230 FEDERAL ST  PITTSBURGH    PA  15212-4704  Allegheny
# 1        1910 BROADWAY AVE  PITTSBURGH    PA  15216-3130  Allegheny
# 2       708 BROOKLINE BLVD  PITTSBURGH    PA  15226-2102  Allegheny
# 3      1811 BROWNSVILLE RD  PITTSBURGH    PA  15210-3907  Allegheny
# 4        612 SMITHFIELD ST  PITTSBURGH    PA  15222-2506  Allegheny
# 5   130 SOUTH WHITFIELD ST  PITTSBURGH    PA  15206-3806  Allegheny
# 6          5006 SECOND AVE  PITTSBURGH    PA  15207-1625  Allegheny
# 7          2177 CENTRE AVE  PITTSBURGH    PA  15219-6316  Allegheny
# 8        7101 HAMILTON AVE  PITTSBURGH    PA  15208-2847  Allegheny
# 9       400 BROWNSVILLE RD  PITTSBURGH    PA  15210-2251  Allegheny
# 10             279 FISK ST  PITTSBURGH    PA  15201-2898  Allegheny
# 11          4724 BAUM BLVD  PITTSBURGH    PA  15213-1321  Allegheny
# 12      4400 FORBES AVENUE  PITTSBURGH    PA  15213-4080  Allegheny
# 13       315 GRANDVIEW AVE  PITTSBURGH    PA  15211-1549  Allegheny
# 14        720 SHERWOOD AVE  PITTSBURGH    PA  15204-1724  Allegheny
# 15        2205 E CARSON ST  PITTSBURGH    PA  15203-2107  Allegheny
# 16         5801 FORBES AVE  PITTSBURGH    PA  15217-1601  Allegheny
# 17           47 WABASH AVE  PITTSBURGH    PA  15220-5422  Allegheny
# 18      1201 WOODS RUN AVE  PITTSBURGH    PA  15212-2335  Allegheny
#
#              Phone    SqFt  ...    ThOpen   ThClose    FrOpen   FrClose  \
# 17  10:00:00  17:00:00       NaN       NaN  40.440057 -80.034045
# 18  10:00:00  17:00:00       NaN       NaN  40.476254 -80.030204
#
# [19 rows x 26 columns]

# %% [markdown]
# The best neighborhoods would be the ones that have libraries open for the most amount of hours. If we want to compare neighborhoods, we can order this information by zip code.

# %%
import csv

with open('libraries.csv') as f:
    data = [row for row in csv.reader(f)]
    zip_codes = []
    for row in data[1:]: # skip the header row using a list slice
        zip_codes.append(row[6])

print(zip_codes)
# Out:
# ['15212-4704', '15216-3130', '15226-2102', '15210-3907', '15222-2506', '15206-3806', '15207-1625', '15219-6316', '15208-2847', '15210-2251', '15201-2898', '15213-1321', '15213-4080', '15211-1549', '15204-1724', '15203-2107', '15217-1601', '15220-5422', '15212-2335']

# %%
# load data
lib_data = pd.read_csv("libraries.csv",index_col="_id")
first_five_digits = lib_data['Zip4'].str[:5]
first_five_digits.value_counts().sort_values(ascending=True)
# Out:
# 15216    1
# 15226    1
# 15222    1
# 15206    1
# 15207    1
# 15219    1
# 15208    1
# 15201    1
# 15211    1
# 15204    1
# 15203    1
# 15217    1
# 15220    1
# 15212    2
# 15210    2
# 15213    2
# Name: Zip4, dtype: int64

# %% [markdown]
# Now let's show this information in a bar graph.

# %%
# load data
lib_data = pd.read_csv("libraries.csv",index_col="_id")
first_five_digits = lib_data['Zip4'].str[:5]
first_five_digits.value_counts().sort_values(ascending=True)

# Count the frequency of each value
value_counts = first_five_digits.value_counts().sort_values(ascending=True)

# Plot the frequencies as a bar plot
value_counts.plot(kind="bar")

# Show the plot
plt.show()

# %% [markdown]
# From this, we can see there are a couple neighborhoods that have multiple libraries. They are the neighborhoods with zip codes: 15212, 15210, and 15213. Perry South, St. Clair, and North Oakland.

# %% [markdown]
# Next, we want to sort by the libraries that are open on saturdays and sundays.

# %%
# concatinate two series together
ser1 = lib_data['SuOpen']
ser2 = lib_data['Zip4'].str[:5]

# note the Series are passed as a list
pd.concat([ser1, ser2], axis=1)
# Out:
#        SuOpen   Zip4
# _id
# 2    12:00:00  15212
# 3         NaN  15216
# 4         NaN  15226
# 5         NaN  15210
# 6         NaN  15222
# 7         NaN  15206
# 8         NaN  15207
# 9         NaN  15219
# 10        NaN  15208
# 11        NaN  15210
# 12        NaN  15201
# 13        NaN  15213
# 14   12:00:00  15213
# 15        NaN  15211
# 16        NaN  15204
# 17   12:00:00  15203
# 18   12:00:00  15217
# 19        NaN  15220
# 20        NaN  15212

# %% [markdown]
# Now let's show this with a visualization.

# %%
# Count the frequency of each value
hours_counts = hours.value_counts().sort_values(ascending=True)

# Plot the frequencies as a bar plot
hours_counts.plot(kind="bar")

# Show the plot
plt.show()

# %% [markdown]
# From this, we see that the only neighborhoods that have libraries open on Sundays, are 15212, 15213, 15203, and 15217. Perry South, North Oakland, South Side Slopes, and Squirrel Hill South, respectively.

# %% [markdown]
# Add a little conclusion.
